# %%
import pandas as pd
credit = pd.read_excel("C:/Users/gusta/Desktop/DNC/Learn_python/Dataset_colabs/clients_renamed.xlsx")

# acess column
#credit[['EDUCATION','MARRIAGE']]
#credit.EDUCATION

#aply filters
credit.filter(like='stat')
# Out:
#        status_pag_set  status_pag_ago  status_pag_ago.1
# 0                   2               2                -1
# 1                  -1               2                 0
# 2                   0               0                 0
# 3                   0               0                 0
# 4                  -1               0                -1
# ...               ...             ...               ...
# 29995               0               0                 0
# 29996              -1              -1                -1
# 29997               4               3                 2
# 29998               1              -1                 0
# 29999               0               0                 0
#
# [30000 rows x 3 columns]

# %%
# acess rows
credit.loc[0:2,'valor_credito']
# Out:
# 0     20000
# 1    120000
# 2     90000
# Name: valor_credito, dtype: int64

# %%
# acess rows with position
credit.iloc[0:2,0:2]
# Out:
#    Unnamed: 0  ID
# 0           0   1
# 1           1   2

# %%
#Acess rows by bool mask
credit[credit["valor_credito"]==20000]
# Out:
#        Unnamed: 0     ID  valor_credito  Gênero  EDUCATION  MARRIAGE  AGE  \
# 0               0      1          20000       2          2         1   24
# 9               9     10          20000       1          3         2   35
# 16             16     17          20000       1          1         2   24
# 46             46     47          20000       2          1         2   22
# 49             49     50          20000       1          1         2   24
# ...           ...    ...            ...     ...        ...       ...  ...
# 29928       29928  29929          20000       1          2         2   42
# 29930       29930  29931          20000       1          2         1   43
# 29940       29940  29941          20000       1          2         1   48
# 29968       29968  29969          20000       1          2         2   34
# 29983       29983  29984          20000       1          2         1   44
#
#        status_pag_set  status_pag_ago  status_pag_ago.1  ...  BILL_AMT3  \
# ...

# %%
credit = pd.read_csv("C:/Users/gusta/Desktop/DNC/Learn_python/Dataset_colabs/credit_card_clients_2.csv")
credit
# Out:
#           ID  LIMIT_BAL      SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  \
# 0          1    20000.0      2.0        2.0       1.0  24.0    2.0    2.0
# 1          2   120000.0      2.0        2.0       2.0  26.0   -1.0    2.0
# 2          3    90000.0      2.0        2.0       2.0  34.0    0.0    0.0
# 3          4    50000.0      2.0        2.0       1.0  37.0    0.0    0.0
# 4          5    50000.0      1.0        2.0       1.0  57.0   -1.0    0.0
# ...      ...        ...      ...        ...       ...   ...    ...    ...
# 30012  30013        NaN      NaN        NaN       NaN   NaN    NaN    NaN
# 30013  30014        NaN      NaN        NaN       NaN   NaN    NaN    NaN
# 30014  30015        NaN      NaN        NaN       NaN   NaN    NaN    NaN
# 30015  30016        NaN      NaN        NaN       NaN   NaN    NaN    NaN
# 30016  30017    30018.0  29999.0    30000.0    5000.0   0.0    1.0    2.0
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
#values type not null or null
credit.notnull()
credit.isnull()
credit[credit['EDUCATION'].isnull()]
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 30002  30003        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 30003  30004        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 30004  30005        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 30005  30006        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 30006  30007        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 30007  30008        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 30008  30009        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 30009  30010        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 30010  30011        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 30011  30012        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 30012  30013        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# ...

# %%
#Excluindo linhas com valores nulos
CREDIT2 = credit[credit['ID'].notna()]
CREDIT2 = credit.dropna(how='all')
CREDIT2
# Out:
#           ID  LIMIT_BAL      SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  \
# 0          1    20000.0      2.0        2.0       1.0  24.0    2.0    2.0
# 1          2   120000.0      2.0        2.0       2.0  26.0   -1.0    2.0
# 2          3    90000.0      2.0        2.0       2.0  34.0    0.0    0.0
# 3          4    50000.0      2.0        2.0       1.0  37.0    0.0    0.0
# 4          5    50000.0      1.0        2.0       1.0  57.0   -1.0    0.0
# ...      ...        ...      ...        ...       ...   ...    ...    ...
# 30012  30013        NaN      NaN        NaN       NaN   NaN    NaN    NaN
# 30013  30014        NaN      NaN        NaN       NaN   NaN    NaN    NaN
# 30014  30015        NaN      NaN        NaN       NaN   NaN    NaN    NaN
# 30015  30016        NaN      NaN        NaN       NaN   NaN    NaN    NaN
# 30016  30017    30018.0  29999.0    30000.0    5000.0   0.0    1.0    2.0
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
#remover duplicatas
import pandas as pd
credit = pd.read_excel("C:/Users/gusta/Desktop/DNC/Learn_python/Dataset_colabs/clients_renamed.xlsx")
#credit.drop_duplicates(subset='ID',keep='first', inplace=True)
credit.describe()
# Out:
#          Unnamed: 0            ID   valor_credito        Gênero     EDUCATION  \
# count  30000.000000  30000.000000    30000.000000  30000.000000  30000.000000
# mean   14999.500000  15000.500000   167484.322667      1.603733      1.853133
# std     8660.398374   8660.398374   129747.661567      0.489129      0.790349
# min        0.000000      1.000000    10000.000000      1.000000      0.000000
# 25%     7499.750000   7500.750000    50000.000000      1.000000      1.000000
# 50%    14999.500000  15000.500000   140000.000000      2.000000      2.000000
# 75%    22499.250000  22500.250000   240000.000000      2.000000      2.000000
# max    29999.000000  30000.000000  1000000.000000      2.000000      6.000000
#
#            MARRIAGE           AGE  status_pag_set  status_pag_ago  \
# count  30000.000000  30000.000000    30000.000000    30000.000000
# mean       1.551867     35.485500       -0.016700       -0.133767
# std        0.521970      9.217904        1.123802        1.197186
# ...
